# %% [markdown]
# <a href="https://colab.research.google.com/github/marcanoyut/Sistema_POO/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Variables

# %%
Usado = "se esta usando"

print(Usado)
# Out:
# se esta usando

# %%
numeros_enteros = 100
decimales_float = 20.5
booleano = True # o False
Listas =[12, "true" ]
Diccionario = {

             "nombre": "yutzura",
             "apellido": "marcano",
             "edad": 35
}
tupla ("texto",100)  #inmutable

# %% [markdown]
# ##Conversion en tipos de variables

# %%
# Metodos para  convertir string Variables, funciones especificas de cada variable


palabra1  = "Hola Mundo"
palabra2  = "!!!!!!!!!!!!!!!!"
frase = "Hola Mundo"+ palabra2
print(frase)
# Out:
# Hola Mundo!!!!!!!!!!!!!!!!

# %%
print (len(frase))
# Out:
# 26

# %%
print(frase.upper()) #da mayuscula lo requerido
# Out:
# HOLA MUNDO!!!!!!!!!!!!!!!!

# %%
print(frase.isdigit)
# Out:
# <built-in method isdigit of str object at 0x7c1d8c4a9d40>

# %%
#El método .upper() en Python se utiliza para convertir todas las letras minúsculas de una cadena de texto (string) en mayúsculas

nombre = "juan"
nombreMay = nombre.upper()
print(nombre)
print(nombreMay)
# Out:
# juan
# JUAN

# %%
nombreNuevo = nombreMay.lower()
print(nombreNuevo)
# Out:
# juan
